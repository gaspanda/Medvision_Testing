# %% [markdown]
# <a href="https://colab.research.google.com/github/gaspanda/Medvision_Testing/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# To clone a public GitHub repository, use the !git clone command.
# Replace 'YOUR_REPO_URL' with the actual URL of the repository you want to clone.
# For example: !git clone https://github.com/openai/gpt-3

# !git clone YOUR_REPO_URL

# After cloning, you can list the contents of the cloned repository to verify.
# For example:
# !ls your_cloned_repo_name
